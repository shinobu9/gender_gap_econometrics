# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
from statsmodels.stats.outliers_influence import variance_inflation_factor  as vif

# %%
df = pd.read_csv('readydata.csv')

# %%
# корреляция возраста и опыта работы
import seaborn as sb
plt.clf()
sb.scatterplot(data=df, x="age", y="experience")
# plt.show()
plt.savefig('exp_age_corr.png')

# %% [markdown]
# ### Base model

# %%
model = smf.ols("np.log(salary) ~ gender + experience + I(experience**2) + education + C(work_field) + has_subs", data=df)
model_est = model.fit()

print("\n------SUMMARY------\n")
print(model_est.summary())

print("\n------Тест Зарембки------\n")
print(model_est.ssr)

print("\n------Тест Голдфелда-Квандта------\n")
print(sms.het_goldfeldquandt(y=model.endog, x=model.exog, idx = 2, split=.3, drop=.4))

print("\n------Тест Глейзера------\n")
from scipy.stats import chi2
model_aux = smf.ols("abs(model_est.resid) ~ has_subs", data=df)
model_aux_est = model_aux.fit()
stat_aux = model_aux_est.ess / ((1 - 2 / np.pi) * np.var(model_est.resid))
print(f"Stat: {stat_aux:5.4f}, Critical value: {chi2.ppf(0.95, df=model_aux.df_model):5.4f}, \
p-value: {1 - chi2.cdf(stat_aux, df=model_aux.df_model):5.4f}")


print("\n------Тест Бройша-Пагана------\n")
# .
print(sms.het_breuschpagan(model_est.resid, model.exog))

print("\n------VIF-тест на мультиколлинеарность------\n")
# 
for i in range(1, model.exog.shape[1]):
    vif_est = vif(model.exog, i)
    print(f"{model_est.params.index[i]:30}: {vif_est:5.4f}")
    

print("\n------Тест Дарбина-Уотсона------\n")
print(sms.durbin_watson(model_est.resid))
# Out:
# ------SUMMARY------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log(salary)   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.296
# Method:                 Least Squares   F-statistic:                     3.200
# Date:                Wed, 21 Dec 2022   Prob (F-statistic):           4.89e-05
# Time:                        05:45:03   Log-Likelihood:                -60.511
# No. Observations:                 116   AIC:                             167.0
# Df Residuals:                      93   BIC:                             230.4
# Df Model:                          22
# Covariance Type:            nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  9.6984      0.485     19.995      0.000       8.735      10.662
# C(work_field)[T.АРМИЯ, МВД, ОРГАНЫ БЕЗОПАСНОСТИ]          -0.2012      0.519     -0.388      0.699      -1.232       0.830
# C(work_field)[T.ВОЕННО-ПРОМЫШЛЕННЫЙ КОМПЛЕКС]              0.7512      0.685      1.097      0.276      -0.609       2.112
# C(work_field)[T.ГРАЖДАНСКОЕ МАШИНОСТРОЕНИЕ]                0.2112      0.527      0.401      0.689      -0.834       1.257
# C(work_field)[T.ДРУГАЯ ОТРАСЛЬ ТЯЖЕЛОЙ ПРОМЫШЛЕННОСТИ]     0.2736      0.502      0.545      0.587      -0.723       1.270
# C(work_field)[T.ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО]            0.2028      0.531      0.382      0.704      -0.853       1.258
# C(work_field)[T.ЗДРАВООХРАНЕНИЕ]                           0.1984      0.521      0.380      0.704      -0.837       1.234
# C(work_field)[T.ЛЕГКАЯ, ПИЩЕВАЯ ПРОМЫШЛЕННОСТЬ]            0.2914      0.508      0.573      0.568      -0.718       1.301
# C(work_field)[T.НАУКА, КУЛЬТУРА]                          -0.0089      0.599     -0.015      0.988      -1.199       1.181
# C(work_field)[T.НЕФТЕГАЗОВАЯ ПРОМЫШЛЕННОСТЬ]               0.4239      0.667      0.635      0.527      -0.901       1.749
# C(work_field)[T.ОБРАЗОВАНИЕ]                              -0.2072      0.502     -0.413      0.681      -1.205       0.790
# C(work_field)[T.ОПЕРАЦИИ С НЕДВИЖИМОСТЬЮ]                 -0.1328      0.677     -0.196      0.845      -1.477       1.211
# C(work_field)[T.СТРОИТЕЛЬСТВО]                             0.2673      0.496      0.539      0.591      -0.718       1.252
# C(work_field)[T.ТОРГОВЛЯ, БЫТОВОЕ ОБСЛУЖИВАНИЕ]            0.0308      0.490      0.063      0.950      -0.942       1.004
# C(work_field)[T.ТРАНСПОРТ, СВЯЗЬ]                          0.1508      0.485      0.311      0.757      -0.812       1.114
# C(work_field)[T.ФИНАНСЫ]                                   0.0566      0.586      0.097      0.923      -1.108       1.221
# C(work_field)[T.ЭНЕРГЕТИЧЕСКАЯ ПРОМЫШЛЕННОСТЬ]             0.2078      0.528      0.394      0.695      -0.840       1.255
# C(work_field)[T.ЮРИСПРУДЕНЦИЯ]                             0.6107      0.588      1.039      0.301      -0.556       1.777
# gender                                                     0.2725      0.103      2.645      0.010       0.068       0.477
# experience                                                 0.0088      0.010      0.895      0.373      -0.011       0.028
# I(experience ** 2)                                        -0.0002      0.000     -1.086      0.280      -0.001       0.000
# education                                                  0.3380      0.111      3.034      0.003       0.117       0.559
# has_subs                                                   0.3141      0.105      2.981      0.004       0.105       0.523
# ==============================================================================
# Omnibus:                        6.804   Durbin-Watson:                   1.726
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                9.467
# Skew:                           0.255   Prob(JB):                      0.00879
# Kurtosis:                       4.304   Cond. No.                     4.48e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.48e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ------Тест Зарембки------
#
# 19.278680758425303
#
# ------Тест Голдфелда-Квандта------
#
# (0.8048532590546006, 0.6605245462547373, 'increasing')
#
# ------Тест Глейзера------
#
# Stat: 0.0992, Critical value: 3.8415, p-value: 0.7528
#
# ------Тест Бройша-Пагана------
#
# (16.61539891674156, 0.7842157255975762, 0.7067274198208772, 0.8221348849651265)
#
# ------VIF-тест на мультиколлинеарность------
#
# C(work_field)[T.АРМИЯ, МВД, ОРГАНЫ БЕЗОПАСНОСТИ]: 6.2189
# C(work_field)[T.ВОЕННО-ПРОМЫШЛЕННЫЙ КОМПЛЕКС]: 2.2447
# C(work_field)[T.ГРАЖДАНСКОЕ МАШИНОСТРОЕНИЕ]: 5.1649
# C(work_field)[T.ДРУГАЯ ОТРАСЛЬ ТЯЖЕЛОЙ ПРОМЫШЛЕННОСТИ]: 11.1023
# C(work_field)[T.ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО]: 5.2619
# C(work_field)[T.ЗДРАВООХРАНЕНИЕ]: 10.8874
# C(work_field)[T.ЛЕГКАЯ, ПИЩЕВАЯ ПРОМЫШЛЕННОСТЬ]: 8.2007
# C(work_field)[T.НАУКА, КУЛЬТУРА]: 3.4063
# C(work_field)[T.НЕФТЕГАЗОВАЯ ПРОМЫШЛЕННОСТЬ]: 2.1304
# C(work_field)[T.ОБРАЗОВАНИЕ]  : 13.0892
# C(work_field)[T.ОПЕРАЦИИ С НЕДВИЖИМОСТЬЮ]: 2.1910
# C(work_field)[T.СТРОИТЕЛЬСТВО]: 11.8226
# C(work_field)[T.ТОРГОВЛЯ, БЫТОВОЕ ОБСЛУЖИВАНИЕ]: 23.3676
# C(work_field)[T.ТРАНСПОРТ, СВЯЗЬ]: 13.9652
# C(work_field)[T.ФИНАНСЫ]      : 3.2599
# C(work_field)[T.ЭНЕРГЕТИЧЕСКАЯ ПРОМЫШЛЕННОСТЬ]: 5.1841
# C(work_field)[T.ЮРИСПРУДЕНЦИЯ]: 3.2730
# gender                        : 1.4776
# experience                    : 10.6011
# I(experience ** 2)            : 10.9950
# education                     : 1.6360
# has_subs                      : 1.2879
#
# ------Тест Дарбина-Уотсона------
#
# 1.7259844961907045

# %% [markdown]
# ### All-variable model

# %%
model = smf.ols("np.log(salary) ~ gender + experience + I(experience**2) + mariage_status + children + health_problems + health_lvl + education + workweek + C(work_field) + has_subs + count_subs", data=df)
model_est = model.fit()

print("\n------SUMMARY------\n")
print(model_est.summary())

print("\n------Тест Зарембки------\n")
print(model_est.ssr)

print("\n------Тест Голдфелда-Квандта------\n")
print(sms.het_goldfeldquandt(y=model.endog, x=model.exog, idx = 2, split=.3, drop=.4))

print("\n------Тест Глейзера------\n")
from scipy.stats import chi2
model_aux = smf.ols("abs(model_est.resid) ~ has_subs", data=df)
model_aux_est = model_aux.fit()
stat_aux = model_aux_est.ess / ((1 - 2 / np.pi) * np.var(model_est.resid))
print(f"Stat: {stat_aux:5.4f}, Critical value: {chi2.ppf(0.95, df=model_aux.df_model):5.4f}, \
p-value: {1 - chi2.cdf(stat_aux, df=model_aux.df_model):5.4f}")


print("\n------Тест Бройша-Пагана------\n")
# .
print(sms.het_breuschpagan(model_est.resid, model.exog))

print("\n------VIF-тест на мультиколлинеарность------\n")
# 
for i in range(1, model.exog.shape[1]):
    vif_est = vif(model.exog, i)
    print(f"{model_est.params.index[i]:30}: {vif_est:5.4f}")
    

print("\n------Тест Дарбина-Уотсона------\n")
print(sms.durbin_watson(model_est.resid))
# Out:
# ------SUMMARY------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log(salary)   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.343
# Method:                 Least Squares   F-statistic:                     3.149
# Date:                Wed, 21 Dec 2022   Prob (F-statistic):           2.38e-05
# Time:                        05:50:00   Log-Likelihood:                -52.609
# No. Observations:                 116   AIC:                             163.2
# Df Residuals:                      87   BIC:                             243.1
# Df Model:                          28
# Covariance Type:            nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  9.5189      0.584     16.296      0.000       8.358      10.680
# C(work_field)[T.АРМИЯ, МВД, ОРГАНЫ БЕЗОПАСНОСТИ]          -0.4673      0.520     -0.899      0.371      -1.501       0.566
# C(work_field)[T.ВОЕННО-ПРОМЫШЛЕННЫЙ КОМПЛЕКС]              0.7204      0.675      1.067      0.289      -0.622       2.063
# C(work_field)[T.ГРАЖДАНСКОЕ МАШИНОСТРОЕНИЕ]                0.2179      0.522      0.418      0.677      -0.819       1.255
# C(work_field)[T.ДРУГАЯ ОТРАСЛЬ ТЯЖЕЛОЙ ПРОМЫШЛЕННОСТИ]     0.2753      0.493      0.559      0.578      -0.704       1.255
# C(work_field)[T.ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО]            0.1668      0.532      0.314      0.755      -0.890       1.224
# C(work_field)[T.ЗДРАВООХРАНЕНИЕ]                           0.0340      0.522      0.065      0.948      -1.003       1.071
# C(work_field)[T.ЛЕГКАЯ, ПИЩЕВАЯ ПРОМЫШЛЕННОСТЬ]            0.2241      0.506      0.443      0.659      -0.781       1.229
# C(work_field)[T.НАУКА, КУЛЬТУРА]                          -0.0095      0.600     -0.016      0.987      -1.202       1.183
# C(work_field)[T.НЕФТЕГАЗОВАЯ ПРОМЫШЛЕННОСТЬ]               0.3959      0.668      0.593      0.555      -0.931       1.723
# C(work_field)[T.ОБРАЗОВАНИЕ]                              -0.2328      0.501     -0.465      0.643      -1.228       0.762
# C(work_field)[T.ОПЕРАЦИИ С НЕДВИЖИМОСТЬЮ]                 -0.2355      0.676     -0.348      0.728      -1.579       1.108
# C(work_field)[T.СТРОИТЕЛЬСТВО]                             0.0381      0.498      0.076      0.939      -0.951       1.028
# C(work_field)[T.ТОРГОВЛЯ, БЫТОВОЕ ОБСЛУЖИВАНИЕ]           -0.0420      0.488     -0.086      0.931      -1.011       0.927
# C(work_field)[T.ТРАНСПОРТ, СВЯЗЬ]                         -0.0308      0.489     -0.063      0.950      -1.003       0.941
# C(work_field)[T.ФИНАНСЫ]                                  -0.0467      0.591     -0.079      0.937      -1.221       1.128
# C(work_field)[T.ЭНЕРГЕТИЧЕСКАЯ ПРОМЫШЛЕННОСТЬ]             0.0754      0.522      0.144      0.885      -0.961       1.112
# C(work_field)[T.ЮРИСПРУДЕНЦИЯ]                             0.3315      0.592      0.560      0.577      -0.844       1.508
# gender                                                     0.2120      0.104      2.035      0.045       0.005       0.419
# experience                                                 0.0121      0.010      1.212      0.229      -0.008       0.032
# I(experience ** 2)                                        -0.0003      0.000     -1.311      0.193      -0.001       0.000
# mariage_status                                            -0.0229      0.106     -0.215      0.830      -0.234       0.188
# children                                                  -0.0041      0.071     -0.058      0.954      -0.145       0.136
# health_problems                                           -0.0094      0.110     -0.086      0.932      -0.228       0.209
# health_lvl                                                -0.1326      0.086     -1.539      0.127      -0.304       0.039
# education                                                  0.4358      0.117      3.722      0.000       0.203       0.669
# workweek                                                   0.0138      0.005      3.026      0.003       0.005       0.023
# has_subs                                                   0.3178      0.103      3.078      0.003       0.113       0.523
# count_subs                                                 0.0014      0.001      1.076      0.285      -0.001       0.004
# ==============================================================================
# Omnibus:                        4.934   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.085   Jarque-Bera (JB):                6.847
# Skew:                          -0.062   Prob(JB):                       0.0326
# Kurtosis:                       4.184   Cond. No.                     4.65e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.65e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ------Тест Зарембки------
#
# 16.82340435519497
#
# ------Тест Голдфелда-Квандта------
#
# (0.48333301253631583, 0.8555302754940448, 'increasing')
#
# ------Тест Глейзера------
#
# Stat: 0.1606, Critical value: 3.8415, p-value: 0.6886
#
# ------Тест Бройша-Пагана------
#
# (19.24512290737566, 0.8904025828176244, 0.6180292712195177, 0.924982604252326)
#
# ------VIF-тест на мультиколлинеарность------
#
# C(work_field)[T.АРМИЯ, МВД, ОРГАНЫ БЕЗОПАСНОСТИ]: 6.6920
# C(work_field)[T.ВОЕННО-ПРОМЫШЛЕННЫЙ КОМПЛЕКС]: 2.3390
# C(work_field)[T.ГРАЖДАНСКОЕ МАШИНОСТРОЕНИЕ]: 5.4385
# C(work_field)[T.ДРУГАЯ ОТРАСЛЬ ТЯЖЕЛОЙ ПРОМЫШЛЕННОСТИ]: 11.4732
# C(work_field)[T.ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО]: 5.6487
# C(work_field)[T.ЗДРАВООХРАНЕНИЕ]: 11.6941
# C(work_field)[T.ЛЕГКАЯ, ПИЩЕВАЯ ПРОМЫШЛЕННОСТЬ]: 8.6933
# C(work_field)[T.НАУКА, КУЛЬТУРА]: 3.6614
# C(work_field)[T.НЕФТЕГАЗОВАЯ ПРОМЫШЛЕННОСТЬ]: 2.2855
# C(work_field)[T.ОБРАЗОВАНИЕ]  : 13.9375
# C(work_field)[T.ОПЕРАЦИИ С НЕДВИЖИМОСТЬЮ]: 2.3436
# C(work_field)[T.СТРОИТЕЛЬСТВО]: 12.7602
# C(work_field)[T.ТОРГОВЛЯ, БЫТОВОЕ ОБСЛУЖИВАНИЕ]: 24.8113
# C(work_field)[T.ТРАНСПОРТ, СВЯЗЬ]: 15.2333
# C(work_field)[T.ФИНАНСЫ]      : 3.5488
# C(work_field)[T.ЭНЕРГЕТИЧЕСКАЯ ПРОМЫШЛЕННОСТЬ]: 5.4330
# C(work_field)[T.ЮРИСПРУДЕНЦИЯ]: 3.5582
# gender                        : 1.6194
# experience                    : 11.5503
# I(experience ** 2)            : 11.6152
# mariage_status                : 1.2363
# children                      : 1.5547
# health_problems               : 1.5007
# health_lvl                    : 1.4915
# education                     : 1.9371
# workweek                      : 1.5638
# has_subs                      : 1.3252
# count_subs                    : 1.1690
#
# ------Тест Дарбина-Уотсона------
#
# 1.9596506054496465

# %% [markdown]
# ### Base + Mariage

# %%
model = smf.ols("np.log(salary) ~ gender + experience + I(experience**2) + mariage_status + education + C(work_field) + has_subs", data=df)
model_est = model.fit()

print("\n------SUMMARY------\n")
print(model_est.summary())

print("\n------Тест Зарембки------\n")
print(model_est.ssr)

print("\n------Тест Голдфелда-Квандта------\n")
print(sms.het_goldfeldquandt(y=model.endog, x=model.exog, idx = 2, split=.3, drop=.4))

print("\n------Тест Глейзера------\n")
from scipy.stats import chi2
model_aux = smf.ols("abs(model_est.resid) ~ has_subs", data=df)
model_aux_est = model_aux.fit()
stat_aux = model_aux_est.ess / ((1 - 2 / np.pi) * np.var(model_est.resid))
print(f"Stat: {stat_aux:5.4f}, Critical value: {chi2.ppf(0.95, df=model_aux.df_model):5.4f}, \
p-value: {1 - chi2.cdf(stat_aux, df=model_aux.df_model):5.4f}")


print("\n------Тест Бройша-Пагана------\n")
# .
print(sms.het_breuschpagan(model_est.resid, model.exog))

print("\n------VIF-тест на мультиколлинеарность------\n")
# 
for i in range(1, model.exog.shape[1]):
    vif_est = vif(model.exog, i)
    print(f"{model_est.params.index[i]:30}: {vif_est:5.4f}")
    

print("\n------Тест Дарбина-Уотсона------\n")
print(sms.durbin_watson(model_est.resid))
# Out:
# ------SUMMARY------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log(salary)   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.289
# Method:                 Least Squares   F-statistic:                     3.029
# Date:                Wed, 21 Dec 2022   Prob (F-statistic):           9.03e-05
# Time:                        05:52:11   Log-Likelihood:                -60.503
# No. Observations:                 116   AIC:                             169.0
# Df Residuals:                      92   BIC:                             235.1
# Df Model:                          23
# Covariance Type:            nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  9.6968      0.488     19.875      0.000       8.728      10.666
# C(work_field)[T.АРМИЯ, МВД, ОРГАНЫ БЕЗОПАСНОСТИ]          -0.1933      0.527     -0.367      0.715      -1.240       0.853
# C(work_field)[T.ВОЕННО-ПРОМЫШЛЕННЫЙ КОМПЛЕКС]              0.7506      0.689      1.090      0.279      -0.617       2.119
# C(work_field)[T.ГРАЖДАНСКОЕ МАШИНОСТРОЕНИЕ]                0.2193      0.535      0.410      0.683      -0.842       1.281
# C(work_field)[T.ДРУГАЯ ОТРАСЛЬ ТЯЖЕЛОЙ ПРОМЫШЛЕННОСТИ]     0.2801      0.508      0.551      0.583      -0.729       1.289
# C(work_field)[T.ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО]            0.2140      0.544      0.393      0.695      -0.867       1.295
# C(work_field)[T.ЗДРАВООХРАНЕНИЕ]                           0.2083      0.532      0.391      0.696      -0.849       1.265
# C(work_field)[T.ЛЕГКАЯ, ПИЩЕВАЯ ПРОМЫШЛЕННОСТЬ]            0.3001      0.517      0.580      0.563      -0.727       1.327
# C(work_field)[T.НАУКА, КУЛЬТУРА]                          -0.0036      0.605     -0.006      0.995      -1.204       1.197
# C(work_field)[T.НЕФТЕГАЗОВАЯ ПРОМЫШЛЕННОСТЬ]               0.4343      0.678      0.641      0.523      -0.912       1.780
# C(work_field)[T.ОБРАЗОВАНИЕ]                              -0.2001      0.509     -0.393      0.695      -1.211       0.811
# C(work_field)[T.ОПЕРАЦИИ С НЕДВИЖИМОСТЬЮ]                 -0.1219      0.688     -0.177      0.860      -1.488       1.244
# C(work_field)[T.СТРОИТЕЛЬСТВО]                             0.2773      0.507      0.547      0.586      -0.730       1.285
# C(work_field)[T.ТОРГОВЛЯ, БЫТОВОЕ ОБСЛУЖИВАНИЕ]            0.0390      0.498      0.078      0.938      -0.951       1.029
# C(work_field)[T.ТРАНСПОРТ, СВЯЗЬ]                          0.1604      0.495      0.324      0.747      -0.824       1.144
# C(work_field)[T.ФИНАНСЫ]                                   0.0671      0.597      0.112      0.911      -1.119       1.253
# C(work_field)[T.ЭНЕРГЕТИЧЕСКАЯ ПРОМЫШЛЕННОСТЬ]             0.2155      0.535      0.403      0.688      -0.847       1.278
# C(work_field)[T.ЮРИСПРУДЕНЦИЯ]                             0.6210      0.598      1.038      0.302      -0.567       1.809
# gender                                                     0.2732      0.104      2.632      0.010       0.067       0.479
# experience                                                 0.0090      0.010      0.897      0.372      -0.011       0.029
# I(experience ** 2)                                        -0.0002      0.000     -1.085      0.281      -0.001       0.000
# mariage_status                                            -0.0118      0.108     -0.109      0.914      -0.227       0.204
# education                                                  0.3390      0.112      3.017      0.003       0.116       0.562
# has_subs                                                   0.3139      0.106      2.962      0.004       0.103       0.524
# ==============================================================================
# Omnibus:                        6.821   Durbin-Watson:                   1.725
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                9.561
# Skew:                           0.252   Prob(JB):                      0.00839
# Kurtosis:                       4.313   Cond. No.                     4.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ------Тест Зарембки------
#
# 19.276206118534198
#
# ------Тест Голдфелда-Квандта------
#
# (0.8225956726140693, 0.6400018870289901, 'increasing')
#
# ------Тест Глейзера------
#
# Stat: 0.1098, Critical value: 3.8415, p-value: 0.7404
#
# ------Тест Бройша-Пагана------
#
# (16.852549904851003, 0.8164239681527206, 0.6798984699527055, 0.8537445785722702)
#
# ------VIF-тест на мультиколлинеарность------
#
# C(work_field)[T.АРМИЯ, МВД, ОРГАНЫ БЕЗОПАСНОСТИ]: 6.3411
# C(work_field)[T.ВОЕННО-ПРОМЫШЛЕННЫЙ КОМПЛЕКС]: 2.2449
# C(work_field)[T.ГРАЖДАНСКОЕ МАШИНОСТРОЕНИЕ]: 5.2679
# C(work_field)[T.ДРУГАЯ ОТРАСЛЬ ТЯЖЕЛОЙ ПРОМЫШЛЕННОСТИ]: 11.2593
# C(work_field)[T.ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО]: 5.4571
# C(work_field)[T.ЗДРАВООХРАНЕНИЕ]: 11.2205
# C(work_field)[T.ЛЕГКАЯ, ПИЩЕВАЯ ПРОМЫШЛЕННОСТЬ]: 8.4010
# C(work_field)[T.НАУКА, КУЛЬТУРА]: 3.4286
# C(work_field)[T.НЕФТЕГАЗОВАЯ ПРОМЫШЛЕННОСТЬ]: 2.1733
# C(work_field)[T.ОБРАЗОВАНИЕ]  : 13.3138
# C(work_field)[T.ОПЕРАЦИИ С НЕДВИЖИМОСТЬЮ]: 2.2381
# C(work_field)[T.СТРОИТЕЛЬСТВО]: 12.2297
# C(work_field)[T.ТОРГОВЛЯ, БЫТОВОЕ ОБСЛУЖИВАНИЕ]: 23.9153
# C(work_field)[T.ТРАНСПОРТ, СВЯЗЬ]: 14.4213
# C(work_field)[T.ФИНАНСЫ]      : 3.3470
# C(work_field)[T.ЭНЕРГЕТИЧЕСКАЯ ПРОМЫШЛЕННОСТЬ]: 5.2773
# C(work_field)[T.ЮРИСПРУДЕНЦИЯ]: 3.3571
# gender                        : 1.4845
# experience                    : 10.7520
# I(experience ** 2)            : 11.0652
# mariage_status                : 1.1922
# education                     : 1.6450
# has_subs                      : 1.2884
#
# ------Тест Дарбина-Уотсона------
#
# 1.7246227053287881

# %% [markdown]
# ### Base + children

# %%
model = smf.ols("np.log(salary) ~ gender + experience + I(experience**2) + mariage_status + children + education + C(work_field) + has_subs", data=df)
model_est = model.fit()

print("\n------SUMMARY------\n")
print(model_est.summary())

print("\n------Тест Зарембки------\n")
print(model_est.ssr)

print("\n------Тест Голдфелда-Квандта------\n")
print(sms.het_goldfeldquandt(y=model.endog, x=model.exog, idx = 2, split=.3, drop=.4))

print("\n------Тест Глейзера------\n")
from scipy.stats import chi2
model_aux = smf.ols("abs(model_est.resid) ~ has_subs", data=df)
model_aux_est = model_aux.fit()
stat_aux = model_aux_est.ess / ((1 - 2 / np.pi) * np.var(model_est.resid))
print(f"Stat: {stat_aux:5.4f}, Critical value: {chi2.ppf(0.95, df=model_aux.df_model):5.4f}, \
p-value: {1 - chi2.cdf(stat_aux, df=model_aux.df_model):5.4f}")


print("\n------Тест Бройша-Пагана------\n")
# .
print(sms.het_breuschpagan(model_est.resid, model.exog))

print("\n------VIF-тест на мультиколлинеарность------\n")
# 
for i in range(1, model.exog.shape[1]):
    vif_est = vif(model.exog, i)
    print(f"{model_est.params.index[i]:30}: {vif_est:5.4f}")
    

print("\n------Тест Дарбина-Уотсона------\n")
print(sms.durbin_watson(model_est.resid))
# Out:
# ------SUMMARY------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log(salary)   R-squared:                       0.431
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     2.871
# Date:                Wed, 21 Dec 2022   Prob (F-statistic):           0.000163
# Time:                        05:53:20   Log-Likelihood:                -60.503
# No. Observations:                 116   AIC:                             171.0
# Df Residuals:                      91   BIC:                             239.8
# Df Model:                          24
# Covariance Type:            nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  9.6987      0.500     19.385      0.000       8.705      10.693
# C(work_field)[T.АРМИЯ, МВД, ОРГАНЫ БЕЗОПАСНОСТИ]          -0.1924      0.532     -0.362      0.718      -1.249       0.864
# C(work_field)[T.ВОЕННО-ПРОМЫШЛЕННЫЙ КОМПЛЕКС]              0.7515      0.694      1.083      0.282      -0.627       2.130
# C(work_field)[T.ГРАЖДАНСКОЕ МАШИНОСТРОЕНИЕ]                0.2184      0.540      0.405      0.687      -0.853       1.290
# C(work_field)[T.ДРУГАЯ ОТРАСЛЬ ТЯЖЕЛОЙ ПРОМЫШЛЕННОСТИ]     0.2806      0.511      0.549      0.585      -0.735       1.296
# C(work_field)[T.ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО]            0.2144      0.547      0.392      0.696      -0.873       1.302
# C(work_field)[T.ЗДРАВООХРАНЕНИЕ]                           0.2095      0.538      0.389      0.698      -0.860       1.279
# C(work_field)[T.ЛЕГКАЯ, ПИЩЕВАЯ ПРОМЫШЛЕННОСТЬ]            0.3008      0.522      0.577      0.565      -0.735       1.337
# C(work_field)[T.НАУКА, КУЛЬТУРА]                          -0.0033      0.608     -0.005      0.996      -1.211       1.204
# C(work_field)[T.НЕФТЕГАЗОВАЯ ПРОМЫШЛЕННОСТЬ]               0.4336      0.682      0.635      0.527      -0.922       1.789
# C(work_field)[T.ОБРАЗОВАНИЕ]                              -0.2001      0.512     -0.391      0.697      -1.217       0.817
# C(work_field)[T.ОПЕРАЦИИ С НЕДВИЖИМОСТЬЮ]                 -0.1215      0.692     -0.176      0.861      -1.496       1.253
# C(work_field)[T.СТРОИТЕЛЬСТВО]                             0.2774      0.510      0.544      0.588      -0.736       1.291
# C(work_field)[T.ТОРГОВЛЯ, БЫТОВОЕ ОБСЛУЖИВАНИЕ]            0.0388      0.501      0.077      0.938      -0.957       1.034
# C(work_field)[T.ТРАНСПОРТ, СВЯЗЬ]                          0.1601      0.498      0.321      0.749      -0.830       1.150
# C(work_field)[T.ФИНАНСЫ]                                   0.0662      0.602      0.110      0.913      -1.130       1.262
# C(work_field)[T.ЭНЕРГЕТИЧЕСКАЯ ПРОМЫШЛЕННОСТЬ]             0.2161      0.539      0.401      0.689      -0.854       1.287
# C(work_field)[T.ЮРИСПРУДЕНЦИЯ]                             0.6213      0.602      1.033      0.305      -0.574       1.816
# gender                                                     0.2735      0.105      2.599      0.011       0.064       0.483
# experience                                                 0.0089      0.010      0.890      0.376      -0.011       0.029
# I(experience ** 2)                                        -0.0002      0.000     -1.078      0.284      -0.001       0.000
# mariage_status                                            -0.0118      0.109     -0.108      0.914      -0.228       0.205
# children                                                  -0.0014      0.072     -0.020      0.984      -0.145       0.142
# education                                                  0.3396      0.118      2.888      0.005       0.106       0.573
# has_subs                                                   0.3138      0.107      2.944      0.004       0.102       0.526
# ==============================================================================
# Omnibus:                        6.851   Durbin-Watson:                   1.726
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                9.644
# Skew:                           0.251   Prob(JB):                      0.00805
# Kurtosis:                       4.320   Cond. No.                     4.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ------Тест Зарембки------
#
# 19.276121371650753
#
# ------Тест Голдфелда-Квандта------
#
# (0.7981887676244557, 0.654854649961857, 'increasing')
#
# ------Тест Глейзера------
#
# Stat: 0.1097, Critical value: 3.8415, p-value: 0.7404
#
# ------Тест Бройша-Пагана------
#
# (16.98538788042188, 0.8492845828517723, 0.6504386339343674, 0.8848426606398927)
#
# ------VIF-тест на мультиколлинеарность------
#
# C(work_field)[T.АРМИЯ, МВД, ОРГАНЫ БЕЗОПАСНОСТИ]: 6.3890
# C(work_field)[T.ВОЕННО-ПРОМЫШЛЕННЫЙ КОМПЛЕКС]: 2.2555
# C(work_field)[T.ГРАЖДАНСКОЕ МАШИНОСТРОЕНИЕ]: 5.3080
# C(work_field)[T.ДРУГАЯ ОТРАСЛЬ ТЯЖЕЛОЙ ПРОМЫШЛЕННОСТИ]: 11.2832
# C(work_field)[T.ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО]: 5.4631
# C(work_field)[T.ЗДРАВООХРАНЕНИЕ]: 11.3583
# C(work_field)[T.ЛЕГКАЯ, ПИЩЕВАЯ ПРОМЫШЛЕННОСТЬ]: 8.4465
# C(work_field)[T.НАУКА, КУЛЬТУРА]: 3.4306
# C(work_field)[T.НЕФТЕГАЗОВАЯ ПРОМЫШЛЕННОСТЬ]: 2.1788
# C(work_field)[T.ОБРАЗОВАНИЕ]  : 13.3138
# C(work_field)[T.ОПЕРАЦИИ С НЕДВИЖИМОСТЬЮ]: 2.2404
# C(work_field)[T.СТРОИТЕЛЬСТВО]: 12.2299
# C(work_field)[T.ТОРГОВЛЯ, БЫТОВОЕ ОБСЛУЖИВАНИЕ]: 23.9257
# C(work_field)[T.ТРАНСПОРТ, СВЯЗЬ]: 14.4347
# C(work_field)[T.ФИНАНСЫ]      : 3.3635
# C(work_field)[T.ЭНЕРГЕТИЧЕСКАЯ ПРОМЫШЛЕННОСТЬ]: 5.2947
# C(work_field)[T.ЮРИСПРУДЕНЦИЯ]: 3.3591
# gender                        : 1.5086
# experience                    : 10.7659
# I(experience ** 2)            : 11.0809
# mariage_status                : 1.1924
# children                      : 1.4812
# education                     : 1.7833
# has_subs                      : 1.2895
#
# ------Тест Дарбина-Уотсона------
#
# 1.7255460725432854

# %% [markdown]
# ### Base + health

# %%
model = smf.ols("np.log(salary) ~ gender + experience + I(experience**2) + health_problems + health_lvl + education + C(work_field) + has_subs", data=df)
model_est = model.fit()

print("\n------SUMMARY------\n")
print(model_est.summary())

print("\n------Тест Зарембки------\n")
print(model_est.ssr)

print("\n------Тест Голдфелда-Квандта------\n")
print(sms.het_goldfeldquandt(y=model.endog, x=model.exog, idx = 2, split=.3, drop=.4))

print("\n------Тест Глейзера------\n")
from scipy.stats import chi2
model_aux = smf.ols("abs(model_est.resid) ~ has_subs", data=df)
model_aux_est = model_aux.fit()
stat_aux = model_aux_est.ess / ((1 - 2 / np.pi) * np.var(model_est.resid))
print(f"Stat: {stat_aux:5.4f}, Critical value: {chi2.ppf(0.95, df=model_aux.df_model):5.4f}, \
p-value: {1 - chi2.cdf(stat_aux, df=model_aux.df_model):5.4f}")


print("\n------Тест Бройша-Пагана------\n")
# .
print(sms.het_breuschpagan(model_est.resid, model.exog))

print("\n------VIF-тест на мультиколлинеарность------\n")
# 
for i in range(1, model.exog.shape[1]):
    vif_est = vif(model.exog, i)
    print(f"{model_est.params.index[i]:30}: {vif_est:5.4f}")
    

print("\n------Тест Дарбина-Уотсона------\n")
print(sms.durbin_watson(model_est.resid))
# Out:
# ------SUMMARY------
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         np.log(salary)   R-squared:                       0.448
# Model:                            OLS   Adj. R-squared:                  0.303
# Method:                 Least Squares   F-statistic:                     3.080
# Date:                Wed, 21 Dec 2022   Prob (F-statistic):           6.00e-05
# Time:                        05:55:03   Log-Likelihood:                -58.710
# No. Observations:                 116   AIC:                             167.4
# Df Residuals:                      91   BIC:                             236.3
# Df Model:                          24
# Covariance Type:            nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                 10.1481      0.553     18.366      0.000       9.051      11.246
# C(work_field)[T.АРМИЯ, МВД, ОРГАНЫ БЕЗОПАСНОСТИ]          -0.3281      0.530     -0.619      0.537      -1.380       0.724
# C(work_field)[T.ВОЕННО-ПРОМЫШЛЕННЫЙ КОМПЛЕКС]              0.6415      0.695      0.924      0.358      -0.738       2.021
# C(work_field)[T.ГРАЖДАНСКОЕ МАШИНОСТРОЕНИЕ]                0.2014      0.530      0.380      0.705      -0.851       1.254
# C(work_field)[T.ДРУГАЯ ОТРАСЛЬ ТЯЖЕЛОЙ ПРОМЫШЛЕННОСТИ]     0.2031      0.505      0.402      0.688      -0.800       1.206
# C(work_field)[T.ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО]            0.0694      0.541      0.128      0.898      -1.005       1.144
# C(work_field)[T.ЗДРАВООХРАНЕНИЕ]                           0.1054      0.530      0.199      0.843      -0.947       1.158
# C(work_field)[T.ЛЕГКАЯ, ПИЩЕВАЯ ПРОМЫШЛЕННОСТЬ]            0.2178      0.515      0.423      0.674      -0.806       1.241
# C(work_field)[T.НАУКА, КУЛЬТУРА]                          -0.1784      0.616     -0.290      0.773      -1.401       1.044
# C(work_field)[T.НЕФТЕГАЗОВАЯ ПРОМЫШЛЕННОСТЬ]               0.2116      0.681      0.311      0.757      -1.140       1.564
# C(work_field)[T.ОБРАЗОВАНИЕ]                              -0.3466      0.511     -0.678      0.500      -1.362       0.669
# C(work_field)[T.ОПЕРАЦИИ С НЕДВИЖИМОСТЬЮ]                 -0.2068      0.692     -0.299      0.766      -1.581       1.168
# C(work_field)[T.СТРОИТЕЛЬСТВО]                             0.1651      0.503      0.328      0.744      -0.834       1.165
# C(work_field)[T.ТОРГОВЛЯ, БЫТОВОЕ ОБСЛУЖИВАНИЕ]           -0.0601      0.498     -0.121      0.904      -1.050       0.930
# C(work_field)[T.ТРАНСПОРТ, СВЯЗЬ]                          0.0315      0.497      0.063      0.950      -0.956       1.019
# C(work_field)[T.ФИНАНСЫ]                                  -0.0911      0.601     -0.152      0.880      -1.285       1.103
# C(work_field)[T.ЭНЕРГЕТИЧЕСКАЯ ПРОМЫШЛЕННОСТЬ]             0.0813      0.534      0.152      0.879      -0.980       1.143
# C(work_field)[T.ЮРИСПРУДЕНЦИЯ]                             0.4726      0.603      0.784      0.435      -0.725       1.670
# gender                                                     0.2421      0.106      2.284      0.025       0.032       0.453
# experience                                                 0.0125      0.010      1.240      0.218      -0.008       0.033
# I(experience ** 2)                                        -0.0003      0.000     -1.278      0.204      -0.001       0.000
# health_problems                                            0.0039      0.110      0.035      0.972      -0.215       0.223
# health_lvl                                                -0.1410      0.088     -1.603      0.112      -0.316       0.034
# education                                                  0.3379      0.111      3.045      0.003       0.118       0.558
# has_subs                                                   0.3022      0.106      2.844      0.006       0.091       0.513
# ==============================================================================
# Omnibus:                        7.532   Durbin-Watson:                   1.788
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):               10.619
# Skew:                           0.295   Prob(JB):                      0.00495
# Kurtosis:                       4.360   Cond. No.                     4.61e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.61e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ------Тест Зарембки------
#
# 18.689492814613818
#
# ------Тест Голдфелда-Квандта------
#
# (0.9372123483878794, 0.5438010655271304, 'increasing')
#
# ------Тест Глейзера------
#
# Stat: 0.0095, Critical value: 3.8415, p-value: 0.9222
#
# ------Тест Бройша-Пагана------
#
# (16.93371859368282, 0.8514751385949306, 0.6481217970727867, 0.8867758460215756)
#
# ------VIF-тест на мультиколлинеарность------
#
# C(work_field)[T.АРМИЯ, МВД, ОРГАНЫ БЕЗОПАСНОСТИ]: 6.5370
# C(work_field)[T.ВОЕННО-ПРОМЫШЛЕННЫЙ КОМПЛЕКС]: 2.3284
# C(work_field)[T.ГРАЖДАНСКОЕ МАШИНОСТРОЕНИЕ]: 5.2782
# C(work_field)[T.ДРУГАЯ ОТРАСЛЬ ТЯЖЕЛОЙ ПРОМЫШЛЕННОСТИ]: 11.3457
# C(work_field)[T.ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО]: 5.5039
# C(work_field)[T.ЗДРАВООХРАНЕНИЕ]: 11.3445
# C(work_field)[T.ЛЕГКАЯ, ПИЩЕВАЯ ПРОМЫШЛЕННОСТЬ]: 8.5045
# C(work_field)[T.НАУКА, КУЛЬТУРА]: 3.6267
# C(work_field)[T.НЕФТЕГАЗОВАЯ ПРОМЫШЛЕННОСТЬ]: 2.2366
# C(work_field)[T.ОБРАЗОВАНИЕ]  : 13.6901
# C(work_field)[T.ОПЕРАЦИИ С НЕДВИЖИМОСТЬЮ]: 2.3112
# C(work_field)[T.СТРОИТЕЛЬСТВО]: 12.2771
# C(work_field)[T.ТОРГОВЛЯ, БЫТОВОЕ ОБСЛУЖИВАНИЕ]: 24.3885
# C(work_field)[T.ТРАНСПОРТ, СВЯЗЬ]: 14.8142
# C(work_field)[T.ФИНАНСЫ]      : 3.4583
# C(work_field)[T.ЭНЕРГЕТИЧЕСКАЯ ПРОМЫШЛЕННОСТЬ]: 5.3674
# C(work_field)[T.ЮРИСПРУДЕНЦИЯ]: 3.4784
# gender                        : 1.5790
# experience                    : 11.1971
# I(experience ** 2)            : 11.3532
# health_problems               : 1.4230
# health_lvl                    : 1.4626
# education                     : 1.6375
# has_subs                      : 1.3214
#
# ------Тест Дарбина-Уотсона------
#
# 1.7880650049516829
